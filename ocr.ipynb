# %%
import easyocr
#reader = easyocr.Reader(['ch_sim','en']) # this needs to run only once to load the model into memory
reader = easyocr.Reader(['en'])
result = reader.readtext('excel-invoice-template-2x.jpg')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result
# Out:
# [([[91, 109], [391, 109], [391, 145], [91, 145]],
#   'Zylker Electronics Hub',
#   0.8572377874731568),
#  ([[130, 150], [254, 150], [254, 174], [130, 174]],
#   'Northern Street',
#   0.7088681409265368),
#  ([[95, 179], [263, 179], [263, 200], [95, 200]],
#   'Greater South Avenue',
#   0.9123796560869802),
#  ([[869, 162], [1125, 162], [1125, 228], [869, 228]],
#   'INVOICE',
#   0.9999574209592083),
#  ([[95, 199], [293, 199], [293, 219], [95, 219]],
#   'New York New York 10001',
#   0.7539906045964658),
#  ([[93, 219], [137, 219], [137, 239], [93, 239]], 'U.SA', 0.5574893355369568),
#  ([[93, 251], [161, 251], [161, 269], [93, 269]],
#   'Invoice#',
#   0.775163792338517),
#  ([[345, 249], [439, 249], [439, 269], [345, 269]],
#   'INV-000003',
#   0.9852362884854243),
#  ([[93, 275], [191, 275], [191, 295], [93, 295]],
#   'Invoice Date',
#   0.8711667744396379),
#  ([[347, 275], [369, 275], [369, 295], [347, 295]], '18', 0.9999989884757856),
# ...
